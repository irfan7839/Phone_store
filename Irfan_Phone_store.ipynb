# %%
class Phone:
    store={}
    def __init__(self,brandName,model,price,unit):
        self.brandName = brandName
        self.model = model
        self.price = price
        self.unit = unit
        Phone.store[brandName] = [[self.model,self.price,self.unit ]]
class Store(Phone):
    def printing():
        print(Phone.store)
    def addBrand():
        brandName = input("Enter BrandName")
        model = input("Enter model")
        price = int(input("Enter price"))
        unit = int(input("Enter unit"))
        Phone1 = Phone(brandName,model,price,unit)
        print("New model update")
    def print_by_Brand():
        brandName = input("Enter BrandName")
        if brandName in Phone.store:
            print(Phone.store[brandName],"\n")
        else:
            print("No Result Found")
    def addModel():
        brandName = input("Enter BrandName")
        model = input("Enter model")
        price = int(input("Enter price"))
        unit = int(input("Enter unit"))
        if brandName in Phone.store:
            Phone.store[brandName].append([model,price,unit])
        else:
            print("No Brand found pleas add by Brand Name")
        
while True:
    phone1=Phone("samsung", "s5", "23000", 7)
    phone2=Phone("sony", "T3", "37000", 17)
    phone1=Phone("iphone", "12pro", "93000", 23)
    phone1=Phone("onePlus", "7", "34000", 7)
    phone1=Phone("samsung", "s5", "23000", 7)
    print("1. for add Brand by BrandName\n")
    print("2. for add Model by ModelName\n")
    print("3. for printing all Brand Phones\n")
    print("4. for printing Phones by ModelName\n")
    print("5. for Exit\n")
    n = int(input())
    if n==1:
        Store.addBrand()
    elif n==2:
        Store.addModel()
    elif n==3:
         Store.printing()
    elif n==4:
        Store.print_by_Brand()
    elif n==5:
        print("Bye Bye!!")
        break
    else:
        print("please Select Correct option")
# Out:
# 1. for add Brand by BrandName
#
# 2. for add Model by ModelName
#
# 3. for printing all Brand Phones
#
# 4. for printing Phones by ModelName
#
# 5. for Exit
#
# 4
# Enter BrandNamesony
# [['T3', '37000', 17]]
#
# 1. for add Brand by BrandName
#
# 2. for add Model by ModelName
#
# 3. for printing all Brand Phones
#
# 4. for printing Phones by ModelName
#
# 5. for Exit
#
# 5
# Bye Bye!!
